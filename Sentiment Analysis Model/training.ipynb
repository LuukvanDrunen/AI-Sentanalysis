# %%
# Transformers installation
! pip install transformers datasets evaluate accelerate
# To install from source instead of the last release, comment the command above and uncomment the following one.
# ! pip install git+https://github.com/huggingface/transformers.git
# Out:
# Requirement already satisfied: transformers in /home/luukv/anaconda3/lib/python3.13/site-packages (4.57.1)
# Requirement already satisfied: datasets in /home/luukv/anaconda3/lib/python3.13/site-packages (4.4.1)
# Requirement already satisfied: evaluate in /home/luukv/anaconda3/lib/python3.13/site-packages (0.4.6)
# Requirement already satisfied: accelerate in /home/luukv/anaconda3/lib/python3.13/site-packages (1.11.0)
# Requirement already satisfied: filelock in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/luukv/anaconda3/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/luukv/anaconda3/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/luukv/anaconda3/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /home/luukv/anaconda3/lib/python3.13/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /home/luukv/anaconda3/lib/python3.13/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /home/luukv/anaconda3/lib/python3.13/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in /home/luukv/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in /home/luukv/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/luukv/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/luukv/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/luukv/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: psutil in /home/luukv/anaconda3/lib/python3.13/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=2.0.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from accelerate) (2.9.1+cu130)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/luukv/anaconda3/lib/python3.13/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: setuptools in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.48 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (13.0.48)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.48 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (13.0.48)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.48 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (13.0.48)
# Requirement already satisfied: nvidia-cudnn-cu13==9.13.0.50 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (9.13.0.50)
# Requirement already satisfied: nvidia-cublas==13.0.0.19 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (13.0.0.19)
# Requirement already satisfied: nvidia-cufft==12.0.0.15 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.0.0.15)
# Requirement already satisfied: nvidia-curand==10.4.0.35 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.3.29 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.0.3.29)
# Requirement already satisfied: nvidia-cusparse==12.6.2.49 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (12.6.2.49)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.27.7 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (2.27.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.3.24 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.3.24)
# Requirement already satisfied: nvidia-nvtx==13.0.39 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (13.0.39)
# Requirement already satisfied: nvidia-nvjitlink==13.0.39 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (13.0.39)
# Requirement already satisfied: nvidia-cufile==1.15.0.42 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (1.15.0.42)
# Requirement already satisfied: triton==3.5.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from torch>=2.0.0->accelerate) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/luukv/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/luukv/anaconda3/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/luukv/anaconda3/lib/python3.13/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/luukv/anaconda3/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/luukv/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# # Fine-tuning

# %% [markdown]
# Fine-tuning adapts a pretrained model to a specific task with a smaller specialized dataset. This approach requires far less data and compute compared to training a model from scratch, which makes it a more accessible option for many users.
#
# Transformers provides the [Trainer](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer) API, which offers a comprehensive set of training features, for fine-tuning any of the models on the [Hub](https://hf.co/models).
#
# > [!TIP]
# > Learn how to fine-tune models for other tasks in our Task Recipes section in Resources!
#
# This guide will show you how to fine-tune a model with [Trainer](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer) to classify Yelp reviews.
#
# Log in to your Hugging Face account with your user token to ensure you can access gated models and share your models on the Hub.

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Start by loading the [Yelp Reviews](https://hf.co/datasets/yelp_review_full) dataset and [preprocess](https://huggingface.co/docs/transformers/main/en/./fast_tokenizers#preprocess) (tokenize, pad, and truncate) it for training. Use [map](https://huggingface.co/docs/datasets/main/en/package_reference/main_classes#datasets.Dataset.map) to preprocess the entire dataset in one step.

# %%
from datasets import load_dataset
from transformers import AutoTokenizer
from transformers import RobertaTokenizer, RobertaForSequenceClassification

dataset = load_dataset("benjaminvdb/dbrd")
tokenizer = RobertaTokenizer.from_pretrained("pdelobelle/robbert-v2-dutch-base")

def tokenize(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

dataset = dataset.map(tokenize, batched=True)

# %% [markdown]
# > [!TIP]
# > Fine-tune on a smaller subset of the full dataset to reduce the time it takes. The results won't be as good compared to fine-tuning on the full dataset, but it is useful to make sure everything works as expected first before committing to training on the full dataset.
# >
# > ```py
# > small_train = dataset["train"].shuffle(seed=42).select(range(1000))
# > small_eval = dataset["test"].shuffle(seed=42).select(range(1000))
# > ```

# %% [markdown]
# ## Trainer

# %%
#@title
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/nvBXf7s7vTI?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# /home/luukv/anaconda3/lib/python3.13/site-packages/IPython/core/display.py:475: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/nvBXf7s7vTI?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# [Trainer](https://huggingface.co/docs/transformers/main/en/./trainer) is an optimized training loop for Transformers models, making it easy to start training right away without manually writing your own training code. Pick and choose from a wide range of training features in [TrainingArguments](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.TrainingArguments) such as gradient accumulation, mixed precision, and options for reporting and logging training metrics.
#
# Load a model and provide the number of expected labels (you can find this information on the Yelp Review [dataset card](https://huggingface.co/datasets/yelp_review_full#data-fields)).

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification

model = RobertaForSequenceClassification.from_pretrained("sytnaxerror/yelp_review_classifier", num_labels=2)
"Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google-bert/bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']"
"You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference."
# Out:
# 'You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.'

# %% [markdown]
# > [!TIP]
# > The message above is a reminder that the models pretrained head is discarded and replaced with a randomly initialized classification head. The randomly initialized head needs to be fine-tuned on your specific task to output meaningful predictions.
#
# With the model loaded, set up your training hyperparameters in [TrainingArguments](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.TrainingArguments). Hyperparameters are variables that control the training process - such as the learning rate, batch size, number of epochs - which in turn impacts model performance. Selecting the correct hyperparameters is important and you should experiment with them to find the best configuration for your task.
#
# For this guide, you can use the default hyperparameters which provide a good baseline to begin with. The only settings to configure in this guide are where to save the checkpoint, how to evaluate model performance during training, and pushing the model to the Hub.
#
# [Trainer](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer) requires a function to compute and report your metric. For a classification task, you'll use [evaluate.load](https://huggingface.co/docs/evaluate/main/en/package_reference/loading_methods#evaluate.load) to load the [accuracy](https://hf.co/spaces/evaluate-metric/accuracy) function from the [Evaluate](https://hf.co/docs/evaluate/index) library. Gather the predictions and labels in [compute](https://huggingface.co/docs/evaluate/main/en/package_reference/main_classes#evaluate.EvaluationModule.compute) to calculate the accuracy.

# %%
import numpy as np
import evaluate

metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    # convert the logits to their predicted class
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %% [markdown]
# Set up [TrainingArguments](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.TrainingArguments) with where to save the model and when to compute accuracy during training. The example below sets it to `"epoch"`, which reports the accuracy at the end of each epoch. Add `push_to_hub=True` to upload the model to the Hub after training.

# %%
# %pip install tf-keras
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="yelp_review_classifier",
    eval_strategy="epoch",
    push_to_hub=True,
)

# %% [markdown]
# Create a [Trainer](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer) instance and pass it the model, training arguments, training and test datasets, and evaluation function. Call [train()](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer.train) to start training.

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    compute_metrics=compute_metrics,
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='7512' max='7512' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7512/7512 45:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.285400</td>
#       <td>0.317325</td>
#       <td>0.922212</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.158600</td>
#       <td>0.339450</td>
#       <td>0.926259</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.056800</td>
#       <td>0.385392</td>
#       <td>0.928507</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=7512, training_loss=0.18079790801476367, metrics={'train_runtime': 2716.611, 'train_samples_per_second': 22.117, 'train_steps_per_second': 2.765, 'total_flos': 1.580876465025024e+16, 'train_loss': 0.18079790801476367, 'epoch': 3.0})

# %% [markdown]
# Finally, use [push_to_hub()](https://huggingface.co/docs/transformers/main/en/main_classes/trainer#transformers.Trainer.push_to_hub) to upload your model and tokenizer to the Hub.

# %%
trainer.push_to_hub()
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/sytnaxerror/yelp_review_classifier/commit/c5e33f6dc6ceedaeabd466ef2cc670c6466733ce', commit_message='End of training', commit_description='', oid='c5e33f6dc6ceedaeabd466ef2cc670c6466733ce', pr_url=None, repo_url=RepoUrl('https://huggingface.co/sytnaxerror/yelp_review_classifier', endpoint='https://huggingface.co', repo_type='model', repo_id='sytnaxerror/yelp_review_classifier'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Resources

# %% [markdown]
# Refer to the Transformers [examples](https://github.com/huggingface/transformers/tree/main/examples) for more detailed training scripts on various tasks. You can also check out the [notebooks](https://huggingface.co/docs/transformers/main/en/./notebooks) for interactive examples.

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model=model, tokenizer=tokenizer)

pipe("Ik premier Schoof even de waarheid gezegd  dat lucht op ,we hebben niks aan deze man gehad , en Rob Jetten 1 zal er nooit komen   .maak je maar op voor nieuwe verkiezingen !")
# Out:
# Device set to use cuda:0
# [{'label': 'LABEL_0', 'score': 0.9996464252471924}]
